# %%
import numpy as np
import a as qtda
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
from scipy.spatial import distance_matrix
from qiskit import ClassicalRegister, Aer, execute

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform

def create_vietoris_rips(points, epsilon, k):
    # Calculate the pairwise distances between points
    distances = squareform(pdist(points))
    
    # Create a dictionary to hold the simplices
    simplices = {i: [] for i in range(k+1)}
    
    # Add the 0-simplices (points) to the simplicial complex
    for i in range(len(points)):
        simplices[0].append((i,))
    
    # Add the higher-dimensional simplices to the simplicial complex
    for dim in range(1, k+1):
        for indices in itertools.combinations(range(len(points)), dim+1):
            # Check if the pairwise distances between all combinations of points
            # in the simplex are less than epsilon
            if all(distances[i][j] < epsilon for i, j in itertools.combinations(indices, 2)):
                simplices[dim].append(indices)
    
    return simplices

# Example usage
m=5
points =2*np.random.rand(m,2) # 10 random 2D points
 # maximum distance between points for an edge to be included
k = 2 # maximum simplex dimension

# %%
# Visualize the points and edges in the complex
epsilon = 1
simplices = create_vietoris_rips(points, epsilon, k)
plt.scatter(points[:,0], points[:,1])
for edge in simplices[1]:
    x = [points[i][0] for i in edge]
    y = [points[i][1] for i in edge]
    plt.plot(x, y, color='gray', linestyle='-')
plt.show()

# %%
# Visualize the points and edges in the complex
epsilon = 1.1
simplices = create_vietoris_rips(points, epsilon, k)
plt.scatter(points[:,0], points[:,1])
for edge in simplices[1]:
    x = [points[i][0] for i in edge]
    y = [points[i][1] for i in edge]
    plt.plot(x, y, color='gray', linestyle='-')
plt.show()

# %%
# Visualize the points and edges in the complex
epsilon = 1.5
simplices = create_vietoris_rips(points, epsilon, k)
plt.scatter(points[:,0], points[:,1])
for edge in simplices[1]:
    x = [points[i][0] for i in edge]
    y = [points[i][1] for i in edge]
    plt.plot(x, y, color='gray', linestyle='-')
plt.show()

# %%
shots = 1000
num_eval_qubits = 5
# epsilons = [0.1, 1.1, 1.5]

data = qtda.Q_persistent_top_spectra(
    data = points,
#     distance_matrix=distance_matrix, 
    max_dimension=3, 
    max_edge_length=2, 
    num_eval_qubits=num_eval_qubits, 
    shots=shots)
# Out:
# Filtration scale:  0.0
#
# Topological order:  0
# Topological order:  1
# calculation terminated because no simplex of dimension 1
#
# Filtration scale:  0.4130265711332963
#
# Topological order:  0
# Topological order:  1
# Topological order:  2
# calculation terminated because no simplex of dimension 2
#
# Filtration scale:  0.47664182385608855
#
# Topological order:  0
# Topological order:  1
# Topological order:  2
# calculation terminated because no simplex of dimension 2
#
# Filtration scale:  0.5029253957129934
#
# Topological order:  0
# Topological order:  1
# Topological order:  2
# Topological order:  3
# calculation terminated because no simplex of dimension 3
#
# Filtration scale:  0.8500853807376767
#
# Topological order:  0
# Topological order:  1
# Topological order:  2
# Topological order:  3
# calculation terminated because no simplex of dimension 3
#
# Filtration scale:  0.8857114424728483
#
# Topological order:  0
# Topological order:  1
# Topological order:  2
# Topological order:  3
# calculation terminated because no simplex of dimension 3
#
# Filtration scale:  1.0338996966495069
#
# Topological order:  0
# Topological order:  1
# Topological order:  2
# Topological order:  3
# calculation terminated because no simplex of dimension 3
#
# Filtration scale:  1.3243873631000407
#
# Topological order:  0
# Topological order:  1
# Topological order:  2
# Topological order:  3
# calculation terminated because no simplex of dimension 3
#
# Filtration scale:  1.7299220315393382
#
# Topological order:  0
# Topological order:  1
# Topological order:  2
# Topological order:  3
# calculation terminated because no simplex of dimension 3
#
# Filtration scale:  1.8448421958184635
#
# Topological order:  0
# Topological order:  1
# Topological order:  2
# Topological order:  3
# calculation terminated because no simplex of dimension 3

# %%
eigenvalue_dict = data.get_eigenvalues()

for eps in eigenvalue_dict.keys():
    print()
    print()
    print('Filtration scale: ', eps)
    for top_order in eigenvalue_dict[eps].keys():
        print()
        print('Topological order: ', top_order)
        print('Number of holes: ', eigenvalue_dict[eps][top_order][0.0])
        print('Dimension of the k-simplex subspace: ', len(data.state_dict[eps][top_order]))
        print('Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces: ')
        print(eigenvalue_dict[eps][top_order])
        display(plot_histogram(data.get_counts()[eps][top_order]))
# Out:
# Filtration scale:  0.0
#
# Topological order:  0
# Number of holes:  3.915
# Dimension of the k-simplex subspace:  5
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 3.915, 5.067084925144828: 0.525, 5.269768322150621: 0.36}
# Filtration scale:  0.4130265711332963
#
# Topological order:  0
# Number of holes:  3.1
# Dimension of the k-simplex subspace:  5
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 3.1, 2.026833970057931: 0.85, 5.067084925144828: 0.425, 5.269768322150621: 0.355}
# Topological order:  1
# Number of holes:  0
# Dimension of the k-simplex subspace:  1
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 0, 2.026833970057931: 0.905, 2.229517367063724: 0.044}
# Filtration scale:  0.47664182385608855
#
# Topological order:  0
# Number of holes:  1.92
# Dimension of the k-simplex subspace:  5
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 1.92, 1.0134169850289656: 1.01, 5.269768322150621: 0.42, 5.067084925144828: 0.445, 3.040250955086896: 0.7, 3.2429343520926897: 0.12}
# Topological order:  1
# Number of holes:  0
# Dimension of the k-simplex subspace:  2
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 0, 3.040250955086896: 0.782, 3.2429343520926897: 0.118, 1.0134169850289656: 0.932}
# Filtration scale:  0.5029253957129934
#
# Topological order:  0
# Number of holes:  1.905
# Dimension of the k-simplex subspace:  5
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 1.905, 3.040250955086896: 1.595, 5.067084925144828: 0.445, 3.2429343520926897: 0.225, 5.269768322150621: 0.38}
# Topological order:  1
# Number of holes:  0
# Dimension of the k-simplex subspace:  3
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 0, 3.040250955086896: 2.289, 2.8375675580811035: 0.105, 3.2429343520926897: 0.354, 3.445617749098483: 0.078}
# Topological order:  2
# Number of holes:  0
# Dimension of the k-simplex subspace:  1
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 0, 3.040250955086896: 0.779, 3.2429343520926897: 0.11, 2.8375675580811035: 0.029, 3.445617749098483: 0.024}
# Filtration scale:  0.8500853807376767
#
# Topological order:  0
# Number of holes:  0.975
# Dimension of the k-simplex subspace:  5
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 0.975, 4.053667940115862: 0.615, 4.2563513371216555: 0.21, 3.040250955086896: 0.695, 5.067084925144828: 0.43, 1.0134169850289656: 0.995, 5.269768322150621: 0.425, 3.2429343520926897: 0.165}
# Topological order:  1
# Number of holes:  0
# Dimension of the k-simplex subspace:  4
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 0, 4.2563513371216555: 0.216, 4.053667940115862: 0.62, 3.040250955086896: 1.532, 3.2429343520926897: 0.268, 1.0134169850289656: 0.868, 3.445617749098483: 0.088}
# Topological order:  2
# Number of holes:  0
# Dimension of the k-simplex subspace:  1
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 0, 3.2429343520926897: 0.11, 3.040250955086896: 0.798, 2.8375675580811035: 0.037}
# Filtration scale:  0.8857114424728483
#
# Topological order:  0
# Number of holes:  0
# Dimension of the k-simplex subspace:  5
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 0, 3.2429343520926897: 0.155, 0.4053667940115862: 0.215, 3.040250955086896: 0.78, 2.229517367063724: 0.11, 4.2563513371216555: 0.885, 0.6080501910173793: 0.665, 5.269768322150621: 0.36, 5.067084925144828: 0.43, 2.4322007640695174: 0.81}
# Topological order:  1
# Number of holes:  0
# Dimension of the k-simplex subspace:  5
# Eigenvalues of the combinatorial laplacian with dimension of corresponding eigenspaces:
# {0.0: 0,